# %%
x=4
print(x)
# Out:
# 4

# %%
array_list=['a','b','c','a','c','d','b']
frequency={}

for item in array_list

# %%
random_list = ['A', 'A', 'B', 'C', 'B', 'D', 'D', 'A', 'B,'C','B]
frequency = {}


for item in random_list:
   
   if item in frequency:
    
      frequency[item] += 1
   else:
      
      frequency[item] = 1


print(frequency)

# %%
list=['ashfaq','tariq','asif']

if 'ashfaq'  in list:
    print('found')
else:
    print('not found')
# Out:
# found

# %%
#append
list1=['moeed','sarwat','ashfaq']
print(list1)
list1.append('kamraan')
print(list1)
# Out:
# ['moeed', 'sarwat', 'ashfaq']
# ['moeed', 'sarwat', 'ashfaq', 'kamraan']

# %%
#insert an element
list=['ashfaq','kamraan','moeed','ahmad']
list.insert(2,'suhail')
print(list)
# Out:
# ['ashfaq', 'kamraan', 'suhail', 'moeed', 'ahmad']

# %%
#extend_list.
#list=['ashfaq','kamraan','moeed','ahmad']
list1=[12,3,11,4,7]
list.extend(list1)
print(list)
# Out:
# ['ashfaq', 'kamraan', 'suhail', 'moeed', 'ahmad', 12, 3, 11, 4, 7]

# %%
list1=[12,3,11,4,7]
list.extend(list1)
print(list)
# Out:
# ['ashfaq', 'kamraan', 'suhail', 'moeed', 'ahmad', 12, 3, 11, 4, 7, 12, 3, 11, 4, 7]

# %%
num=5
print(num,type(num))

num1="a"
print(num1,type(num1))
# Out:
# 5 <class 'int'>
# a <class 'str'>

# %%
input_var=input("please enter the value")
print(input_var)

# %%
my_fav_num=input("Enter your favourite number : ")
print("your favourite number is : ",my_fav_num)

# %%
my_fav_num = input("Enter your favourite number: ")

try:
    my_fav_num = int(my_fav_num)  # Try converting to an integer
except ValueError:
    try:
        my_fav_num = float(my_fav_num)  # Try converting to a float
    except ValueError:
        print("The input is not a valid number.")

print("Your favourite number is:", my_fav_num)

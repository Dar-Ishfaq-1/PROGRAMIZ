# %%
x=3
print(x)
# Out:
# 3

# %%
x='ashfaqi'
print(x)
# Out:
# ashfaqi

# %%
name = 'kamraan'
age = 27
print('My name is ',name)
print("and i am", age ,"year old")
# Out:
# My name is  kamraan
# and i am 27 year old

# %%
x='my name is '
print(x +"ashfaq")
# Out:
# my name is ashfaq

# %%
a,b,=10,1000
print('The value of a is {} and b is {}'.format(a,b))
# Out:
# The value of a is 10 and b is 1000

# %%
n = input('Enter the number: ')
print("entered number is ",n)
print(type)
# Out:
# entered number is  3
# <class 'type'>

# %%
n = input('Enter the Number: ')

print('Number Entered by User:',n)

print(type(n))
# Out:
# Number Entered by User: 2
# <class 'str'>

# %%
#type casting 
x=str(5)
y=int(5)
z=float(5)
print(x,y,z,sep='\t')
# Out:
# 5	5	5.0

# %%
x = str(5)
y = int(5)
z = float(5)

print("{} {} {}".format(x, y, z))
# Out:
# 5 5 5.0

# %%
x = str(5)
y = int(5)
z = float(5)
          
print(f"{x} {y} {z}")
# Out:
# 5 5 5.0

# %%
name = "kamraan"
age = 26
formatted_string = "my name is {} and i am {} years old. ".format(name,age)
print(formatted_string)
# Out:
# my name is kamraan and i am 26 years old.

# %%
name = "ashfaq"
age= 27 
formatted_string = f"My name is {name} and i am {age} years old ."
print(formatted_string)
# Out:
# My name is ashfaq and i am 27 years old .

# %%
print('*\t' *4)
# Out:
# *	*	*	*

# %%
price = 10
rating = 2.3
name = 'ashfaq'
is_published = True
